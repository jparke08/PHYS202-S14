# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(10, 6), dpi=80)

#Plot of Data
frequency = np.array([2.96,2.83,2.6,2.387,2.18,1.963,1.824,1.646,1.425])
gamma = .067*((2*np.pi*frequency)**2)/9.8
ticks = np.array([12,11.5,10.5,8.5,6.5,4,3,1,.5])
phi = (ticks * 5)*(np.pi/180)
plt.scatter(gamma,phi,s=5,c = 'r',marker = 'o',label='Data');

#Theoretical Plot
gamma2 = np.linspace(1,2.5,30)
phi2 = np.arccos(1/gamma2)
plt.plot(gamma2,phi2,color = 'k')
plt.plot(gamma2,-phi2,color = 'k')
plt.plot(np.linspace(0,1,2),[0,0],color = 'k',label = 'Theoretical(stable)')
plt.plot(np.linspace(1,2.5,2),[0,0],color = 'black',linestyle = '--',label= 'Theoretical(unstable)')

#Clean Up Graph
plt.xlim(0, 2.5)

ax = plt.gca() 
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(direction='out', top=False, right=False)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
plt.xlabel("Gamma",fontsize=20)
plt.ylabel("Phi",fontsize=20)

plt.legend(loc ='upper left',fontsize = 10)

# %%
x = np.arange(-2.5,2.6,.1)
y1 = 3*x - x**3
y2 =  x
plt.plot(x,y1,x,y2)
plt.ylim(-7,7)
plt.grid()

# %%
plt.figure(figsize=(10, 6), dpi=80)

#Plot of Data
frequency = np.array([1.525,1.7,2,2.2,2.3,2.5,2.7,2.9,3,3.2,3.4,3.6])
gamma = .0762*((2*np.pi*frequency)**2)/9.8
#ticks = np.array([12,11.5,10.5,8.5,6.5,4,3,1,.5])
phi = np.array([.0717,.2463,.4095,.6513,.6452,.9140,.9509,.9804,1.2114,1.2551,1.2611,1.216])
plt.scatter(gamma,phi,s=5,c = 'r',marker = 'o',label='Data');

#Theoretical Plot
gamma2 = np.linspace(1,2.5,30)
phi2 = np.arccos(1/gamma2)
plt.plot(gamma2,phi2,color = 'k')
plt.plot(gamma2,-phi2,color = 'k')
plt.plot(np.linspace(0,1,2),[0,0],color = 'k',label = 'Theoretical(stable)')
plt.plot(np.linspace(1,2.5,2),[0,0],color = 'black',linestyle = '--',label= 'Theoretical(unstable)')

#Clean Up Graph
plt.xlim(0, 2.5)

ax = plt.gca() 
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(direction='out', top=False, right=False)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
plt.xlabel("Gamma",fontsize=20)
plt.ylabel("Phi",fontsize=20)

plt.legend(loc ='upper left',fontsize = 10)

# %%
plt.figure(figsize=(10, 6), dpi=80)
w1 = np.linspace(0.,20.,50)
b1 = np.sqrt(48*(w1**2)-(790916/(w1**2)))/570

w2 = np.linspace(0.,20.,50)
b2 = np.sqrt(6148-48*(w2**2))/570


plt.plot(w1,b1)
plt.plot(w2,b2)
plt.plot([11.34,11.34],[0,.25],linestyle='--')

plt.xlim(0,20)
plt.xticks([0,5,10,11.34,15,20],[0,5,10,r'$\omega_c$',15,20])

plt.xlabel(r"$\omega (rad/s)$",fontsize=15)
plt.ylabel(r"$b$",fontsize=15)



#annotation
plt.annotate(r'$b=\frac{1}{570}\sqrt{6148-48w^2}$',(3,.13), xytext=(5,.17),fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.annotate(r'$b=\frac{1}{570}\sqrt{48w^2-\frac{790916}{w^2}}$',(13,.1), xytext=(12,.2),fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

ax = plt.gca() 
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(direction='out', top=False, right=False)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)

# %%
x = np.linspace(0.,20.,50)
y = np.sqrt(48*(w**2)-(790916/(w**2)))

plt.plot(x,y)

# %%
x = np.linspace(0.,20.,50)
y = np.sqrt(48*(w**2)-(78916/(w**2)))
# Out:
#   File "<ipython-input-24-da84ea36a9e6>", line 2
#     y = np.sqrt(48*(w**2)-(78916/(w**2))
#                                         ^
# SyntaxError: invalid syntax

# %%
plt.xticks?
